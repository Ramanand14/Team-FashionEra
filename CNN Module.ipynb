# %%
pip install --ignore-installed --upgrade tensorflow

# %%
conda install tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
# Out:
# tensorflow-base-2.3. | 49.5 MB   | ###1       |  32%
# tensorflow-base-2.3. | 49.5 MB   | ###1       |  32%
# tensorflow-base-2.3. | 49.5 MB   | ###1       |  32%
# tensorflow-base-2.3. | 49.5 MB   | ###1       |  32%
# tensorflow-base-2.3. | 49.5 MB   | ###2       |  32%
# tensorflow-base-2.3. | 49.5 MB   | ###2       |  32%
# tensorflow-base-2.3. | 49.5 MB   | ###2       |  33%
# tensorflow-base-2.3. | 49.5 MB   | ###2       |  33%
# tensorflow-base-2.3. | 49.5 MB   | ###2       |  33%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  33%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  33%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  33%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  33%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  34%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  34%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  34%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  34%
# tensorflow-base-2.3. | 49.5 MB   | ###3       |  34%
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
x_train = train_datagen.flow_from_directory(r"C:\IBM Hack Challenge\Input_dataset\traindataset", target_size = (64, 64), batch_size = 32, class_mode = "categorical")
x_test = test_datagen.flow_from_directory(r"C:\IBM Hack Challenge\Input_dataset\testdataset", target_size = (64, 64), batch_size = 32, class_mode = "categorical")
# Out:
# Found 345 images belonging to 3 classes.
# Found 326 images belonging to 3 classes.

# %%
x_train.class_indices
# Out:
# {'Type-I': 0, 'Type-II': 1, 'Type-III': 2}

# %%
model = Sequential()

# %%
model.add(Convolution2D(32, (3, 3),input_shape = (64, 64, 3) ,activation = "relu"))

# %%
model.add(MaxPooling2D(pool_size = (2, 2)))

# %%
model.add(Flatten())

# %%
model.add(Dense(units = 128, kernel_initializer = "random_uniform", activation = "relu"))

# %%
model.add(Dense(units = 128, kernel_initializer = "random_uniform", activation = "relu"))

# %%
model.add(Dense(units = 3, kernel_initializer = "random_uniform", activation = "softmax"))

# %%
model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
model.fit_generator(x_train, steps_per_epoch = 10, epochs = 25, validation_data = x_test, validation_steps = 20)
# Out:
# Epoch 1/25
# ...
# 10/10 [==============================] - 115s 12s/step - loss: 1.0924 - accuracy: 0.5208 - val_loss: 1.0880 - val_accuracy: 0.5000
# Epoch 2/25
# 10/10 [==============================] - 40s 4s/step - loss: 1.0830 - accuracy: 0.5335
# Epoch 3/25
# 10/10 [==============================] - 25s 2s/step - loss: 1.0772 - accuracy: 0.5304
# Epoch 4/25
# 10/10 [==============================] - 23s 2s/step - loss: 1.0747 - accuracy: 0.5094
# Epoch 5/25
# 10/10 [==============================] - 20s 2s/step - loss: 1.0657 - accuracy: 0.5367
# Epoch 6/25
# 10/10 [==============================] - 23s 2s/step - loss: 1.0639 - accuracy: 0.5208
# Epoch 7/25
# 10/10 [==============================] - 22s 2s/step - loss: 1.0580 - accuracy: 0.5304
# Epoch 8/25
# 10/10 [==============================] - 22s 2s/step - loss: 1.0572 - accuracy: 0.5176
# Epoch 9/25
# 10/10 [==============================] - 21s 2s/step - loss: 1.0530 - accuracy: 0.5208
# Epoch 10/25
# ...

# %%
model.save("color.h5")
